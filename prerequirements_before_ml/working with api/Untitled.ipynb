# %%
import requests

url = "https://api.themoviedb.org/3/trending/movie/day?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4MDA4ZGFhOTg1NjZiNzdmMjA0OTUwMjg1NWI5MTVhZCIsIm5iZiI6MTc3NzYwODIzMC43MDU5OTk5LCJzdWIiOiI2OWY0MjYyNjIwYmQ3YTlhYmNmN2UwMTIiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.rnbRexXj3QJJysU0xumKGQ-QVy-9jxVFcM9PXyh_BD0"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/Af907x5h9W1wVis8XrSd7ynTWuy.jpg","id":1314481,"title":"The Devil Wears Prada 2","original_title":"The Devil Wears Prada 2","overview":"Andy Sachs returns to Runway as Miranda Priestly navigates a new media landscape and Runway's position within. The duo reconnect with former assistant Emily Charlton, now the head of a luxury brand that possesses funding which could ensure Runway's survival.","poster_path":"/sRTYF65JvbHLoC3LoBj4UKYqIlA.jpg","media_type":"movie","original_language":"en","genre_ids":[35,18],"popularity":139.4225,"release_date":"2026-04-29","softcore":false,"video":false,"vote_average":6.286,"vote_count":70},{"adult":false,"backdrop_path":"/xBT0oNq6rsTFv4SxG5uGRIEOrq6.jpg","id":936075,"title":"Michael","original_title":"Michael","overview":"The story of Michael Jackson, one of the most influential artists the world has ever known, and his life beyond the music. His journey from the discovery of his extraordinary talen
# ...

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/Af907x5h9W1wVis8XrSd7ynTWuy.jpg',
#    'id': 1314481,
#    'title': 'The Devil Wears Prada 2',
#    'original_title': 'The Devil Wears Prada 2',
#    'overview': "Andy Sachs returns to Runway as Miranda Priestly navigates a new media landscape and Runway's position within. The duo reconnect with former assistant Emily Charlton, now the head of a luxury brand that possesses funding which could ensure Runway's survival.",
#    'poster_path': '/sRTYF65JvbHLoC3LoBj4UKYqIlA.jpg',
#    'media_type': 'movie',
#    'original_language': 'en',
#    'genre_ids': [35, 18],
#    'popularity': 139.4225,
#    'release_date': '2026-04-29',
#    'softcore': False,
#    'video': False,
#    'vote_average': 6.286,
#    'vote_count': 70},
#   {'adult': False,
#    'backdrop_path': '/xBT0oNq6rsTFv4SxG5uGRIEOrq6.jpg',
#    'id': 936075,
#    'title': 'Michael',
#    'original_title': 'Michael',
# ...
