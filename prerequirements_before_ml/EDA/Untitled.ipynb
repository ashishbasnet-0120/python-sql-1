# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install Ydata-profiling

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file('analysis.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2 prof=ProfileReport(df)
#       3 prof.to_file('analysis.html')
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
# ...

# %%
import sys

# %%
# !pip install --upgrade setuptools

# %%
# !pip uninstall ydata-profiling -y
# Out:
# Found existing installation: ydata-profiling 4.18.4
# Uninstalling ydata-profiling-4.18.4:
#   Successfully uninstalled ydata-profiling-4.18.4

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# ...
# Using cached ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# ...

# %%
import sys
import subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "setuptools", "--upgrade"], check=True)
# Out:
# CompletedProcess(args=['C:\\Users\\acer\\anaconda3\\python.exe', '-m', 'pip', 'install', 'setuptools', '--upgrade'], returncode=0)

# %%
import sweetviz as sv
report = sv.analyze(df)
report.show_html("analysis.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report analysis.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "sweetviz"], check=True)
# Out:
# CompletedProcess(args=['C:\\Users\\acer\\anaconda3\\python.exe', '-m', 'pip', 'install', 'sweetviz'], returncode=0)

# %%
import sys
print(sys.version)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
