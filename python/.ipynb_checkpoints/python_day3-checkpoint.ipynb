# %%
# fror loop 

for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in "Ashish":
    print(i)
# Out:
# A
# s
# h
# i
# s
# h

# %%
for z in range(0,10,2):
    print(z)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
# simple calculation

x=10000
for i in range(10,0,-1):
    print(i,x)
    x=x/1.1
# Out:
# 10 10000
# 9 9090.90909090909
# 8 8264.462809917353
# 7 7513.148009015775
# 6 6830.134553650703
# 5 6209.213230591548
# 4 5644.739300537771
# 3 5131.5811823070635
# 2 4665.07380209733
# 1 4240.976183724845

# %%
# nested loop 
# you can visualize it by going to python tutor



for i in range(1,5):
    for j in range(1,6):
        print(i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 1 4
# 1 5
# 2 1
# 2 2
# 2 3
# 2 4
# 2 5
# 3 1
# 3 2
# 3 3
# 3 4
# 3 5
# 4 1
# 4 2
# 4 3
# 4 4
# 4 5

# %%
# pattern 
row=int(input("enter the amount of row:"))
for i in range(1,row+1):
    for j in range(1,i+1):
        print("*",end="")
    print("")
# Out:
# enter the amount of row: 5
# *
# **
# ***
# ****
# *****

# %%
# inverted half pyramid

half=int(input("enter the no of rows:"))

for i in range(half+1,0,-1):
    for j in range(0,i):
        print("*",end="")
    print("")
# Out:
# enter the no of rows: 5
# ******
# *****
# ****
# ***
# **
# *

# %%
# break statement

for i in "Ashish":
    if i=="s":
        print(i)
        break
# Out:
# s

# %%
for i in range(1,20):
    if i==10:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# prime number using break statement
start=int(input("enter the initial condition:"))
end=int(input("enter the stopping condition:"))

for i in range(start,end+1):
    if i<2:
        continue
    for j in range(2,i):
        if i%j==0:
            break
    else:
            print(i)
# Out:
# enter the initial condition: 2
# enter the stopping condition: 5
# 2
# 3
# 5

# %%
# pass staement 

for i in range(1,100):
    pass
for j in range(1,2):
    print(j)
# Out:
# 1

# %%
# strings in pythons

product="Suman basnet"
print(product)
# Out:
# Suman basnet

# %%
# positive accessing
print(product[2])
# Out:
# m

# %%
#negative accessing
print(product[-2])
# Out:
# e

# %%
#length  of sting
len(product)
# Out:
# 12

# %%
# slicing in strings

q="hello, ramu"

print(q[0:])
# Out:
# hello, ramu

# %%
q="hello, ramu"

print(q[:])
# Out:
# hello, ramu

# %%
q="hello, ramu"

print(q[:12])
# Out:
# hello, ramu

# %%
# reversing of strings 

q="hello, ramu"

print(q[12::-1])
# Out:
# umar ,olleh

# %% [markdown]
# ### strings are immutable in python, means any kind of addition, deletion and edition is not possible once its defined

# %%
# string operations in python 


# arithmetic operations 

print("Ashish"+" "+"Basnet")
# Out:
# Ashish Basnet

# %%
print("Ashish "*5)
# Out:
# Ashish Ashish Ashish Ashish Ashish

# %%
#relational operations 
#Strings are compared character by character

#Comparison is based on Unicode values

#Uppercase and lowercase matter

print("Ashish">"Basnet")
print("Ashish"=="Basnet")
print("Ashish"!="Basnet")
print("Ashish"<="Basnet")
print("Ashish">="Basnet")
# Out:
# False
# False
# True
# True
# False

# %%
#logical operations 

print("Manish"and "")
print("Manish"or "")
# Out:
# Manish

# %%
# loop operation 

for i in "baishakh":
    print("KATHMANDU")
# Out:
# KATHMANDU
# KATHMANDU
# KATHMANDU
# KATHMANDU
# KATHMANDU
# KATHMANDU
# KATHMANDU
# KATHMANDU

# %%
# membership operations 
"Ash"in "Bashish"
# Out:
# False

# %%
"R" in"Ram"
# Out:
# True

# %% [markdown]
# ### string functions/methods in python

# %%
### common functions require argument inside it 

bag="this Bag is red"
len(bag)
# Out:
# 15

# %%
sorted(bag)
# Out:
# [' ', ' ', ' ', 'B', 'a', 'd', 'e', 'g', 'h', 'i', 'i', 'r', 's', 's', 't']

# %%
min(bag)
# Out:
# ' '

# %%
max(bag)
# Out:
# 't'

# %%
# special functions can be done by .method 
#capitalize


bag.capitalize()
# Out:
# 'This bag is red'

# %%
#title

bag.title()
# Out:
# 'This Bag Is Red'

# %%
#uppercase
bag.upper()
# Out:
# 'THIS BAG IS RED'

# %%
bag.lower()
# Out:
# 'this bag is red'

# %%
# count function

bag.count("i")
# Out:
# 2

# %%
# difference between index and find function 



# index
bag.index("z")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[155], line 6
#       1 # difference between index and find function
#       2
#       3
#       4
#       5 # index
# ----> 6 bag.index("z")
#
# ValueError: substring not found

# %%
# find
bag.find("z")
# Out:
# -1

# %% [markdown]
# ### f- string in python

# %%
name=input("enter your name:")
age=int(input("enter your age:"))

print(f"your name is {name} and your age will be {2+age} after 2 years. ")
# Out:
# enter your name: suman
# enter your age: 15
# your name is suman and your age will be 17 after 2 years.
