# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
iris=sns.load_dataset('iris')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 98            5.1          2.5           3.0          1.1  versicolor
# 75            6.6          3.0           4.4          1.4  versicolor
# 79            5.7          2.6           3.5          1.0  versicolor
# 130           7.4          2.8           6.1          1.9   virginica
# 110           6.5          3.2           5.1          2.0   virginica

# %% [markdown]
# ### categorical scatter plot

# %%
# stripplot-->  axes level function

# catplot() --->   figure level function 


sns.stripplot(data=tips,x='day', y='tip')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.catplot(data=tips,x='day', y='tip',kind='strip',jitter=False)

# %%
sns.catplot(data=tips,x='day', y='tip',kind='strip',jitter=0.2)

# %%
sns.catplot(data=tips,x='day', y='tip',kind='strip', hue='sex')

# %%
# swarmplot
sns.catplot(data=tips,x='day', y='tip',kind='swarm', hue='sex')
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # boxplot

# %%
  # for single column

sns.boxplot(data=tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# for comparing boxplots or for categorical column as well


sns.catplot(data=tips,x='day',y='total_bill',kind='box')

# %%
# hue parameter

sns.catplot(data=tips,x='day',y='total_bill',kind='box',hue='sex')

# %% [markdown]
# # violinplot

# %%
sns.violinplot(data=tips, x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips, x='day',y='total_bill',kind='violin',hue='sex')

# %%
# split

sns.catplot(data=tips, x='day',y='total_bill',kind='violin',hue='sex',split=True)

# %% [markdown]
# ## barplot
#
# #### by default estimator is mean we can change it

# %%
sns.barplot(data=tips,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# error bar is created when the x axis values gets repeated

# removing errorbar

sns.barplot(data=tips,x='sex',y='total_bill',estimator='median',errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# hue
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker',estimator="var")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### point plot
#
# ##### shows the average (or other estimate) of a numeric variable for different categories using points instead of bars.

# %%
# using figure level function

sns.catplot(data=tips,x='sex',y='total_bill',estimator='median',kind='point')

# %%
# using hue
sns.catplot(data=tips,x='sex',y='total_bill',estimator='median',kind='point',hue='smoker')

# %%
# removing errorbars
sns.catplot(data=tips,x='sex',y='total_bill',estimator='median',kind='point',errorbar=None)

# %%
sns.catplot(data=tips,x='sex',y='total_bill',estimator='median',kind='point',errorbar=None,hue='smoker')

# %% [markdown]
# #### countplot

# %%
sns.countplot(data=tips, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.catplot(data=tips,x='sex',hue='day',kind='count')

# %% [markdown]
# ## regressionplot
#
#
# #### 1. regplot()  --> axes level function
# ###  2. lmplot() --> figure level function

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# hue parameter is not available
sns.regplot(data=tips,x='tip',y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.lmplot(data=tips, x='tip',y='total_bill')

# %%
# hue parameter



sns.lmplot(data=tips, x='tip',y='total_bill',hue='sex')

# %%
# residplot()



sns.residplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### plotting pairwise relation(pairgrid vs pairplot)

# %%
# pairplot
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')

# %%
#  pairgrid



g=sns.PairGrid(data=iris,hue='species')
g.map(sns.scatterplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.kdeplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.histplot)

# %%
#  restricting making grid using vars 

# only apply grid which we provided


g=sns.PairGrid(data=iris,hue='species',vars=['sepal_length','sepal_width'])
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# jointpolt
sns.jointplot(data=tips,x='total_bill',y='tip')  # default

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='hist',hue='sex')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='kde',hue='sex')

# %%
# jointgrid


g=sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.violinplot)

# %%
g=sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.kdeplot,sns.violinplot)

# %%
g=sns.JointGrid(data=tips,x='total_bill',y='tip',hue='sex')
g.plot(sns.scatterplot,sns.violinplot)

# %%
# utility fuctions


sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
