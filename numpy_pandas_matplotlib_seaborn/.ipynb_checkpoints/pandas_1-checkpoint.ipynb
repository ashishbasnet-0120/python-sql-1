# %%
# importing pandas

import numpy as np
import pandas as pd

# %%
# creating series from list

# strings

fruits=["Apple","Mango","Banana","Orange"]
pd.Series(fruits)
# Out:
# 0     Apple
# 1     Mango
# 2    Banana
# 3    Orange
# dtype: object

# %%
# integers

roll=[100,23,45,67,89]
pd.Series(roll)
# Out:
# 0    100
# 1     23
# 2     45
# 3     67
# 4     89
# dtype: int64

# %%
#custom index
marks=[14,34,56,78]
subj=["Nepali","science","English","Social"]

pd.Series(marks,index=subj)
# Out:
# Nepali     14
# science    34
# English    56
# Social     78
# dtype: int64

# %%
# setting a name or provide a additional information with the help of attribute name

jobs=["DS","ML","DL"]
sal=[12000,3000000,400000]
job_info=pd.Series(sal,index=jobs,name="salary of AI/ML engineer ")
job_info
# Out:
# DS      12000
# ML    3000000
# DL     400000
# Name: salary of AI/ML engineer , dtype: int64

# %%
# series from dictionary

marks={
    "social":45,
    "English":100,
    "Maths":60
}

marks_info=pd.Series(marks,name="Marks of mine")
marks_info
# Out:
# social      45
# English    100
# Maths       60
# Name: Marks of mine, dtype: int64

# %%
# series attributes 

# size

job_info
# Out:
# DS      12000
# ML    3000000
# DL     400000
# Name: salary of AI/ML engineer , dtype: int64

# %%
job_info.size
# Out:
# 3

# %%
# dtype

job_info.dtype
# Out:
# dtype('int64')

# %%
#name

job_info.name
# Out:
# 'salary of AI/ML engineer '

# %%
#is_unique
job_info.is_unique
# Out:
# True

# %%
#index
job_info.index
# Out:
# Index(['DS', 'ML', 'DL'], dtype='object')

# %%
#values
job_info.values
# Out:
# array([  12000, 3000000,  400000], dtype=int64)

# %%
type(job_info.values)
# Out:
# numpy.ndarray

# %%
# real world data 

# series using read_csv


type(pd.read_csv(r'C:\Users\acer\Python-Sql-1\numpy_pandas_matplotlib_seaborn_15\dataset_16_pandas\subs.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
type(pd.read_csv(r'C:\Users\acer\Python-Sql-1\numpy_pandas_matplotlib_seaborn_15\dataset_16_pandas\subs.csv').squeeze())
# Out:
# pandas.core.series.Series

# %%
subs=pd.read_csv(r'C:\Users\acer\Python-Sql-1\numpy_pandas_matplotlib_seaborn_15\dataset_16_pandas\subs.csv').squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 columns 

kohli=pd.read_csv(r"C:\Users\acer\Python-Sql-1\numpy_pandas_matplotlib_seaborn_15\dataset_16_pandas\kohli_ipl.csv",index_col='match_no').squeeze()
kohli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# upper kernel we got the result name as runs because basically name is a values we provide

# %%
movie=pd.read_csv(r"C:\Users\acer\Python-Sql-1\numpy_pandas_matplotlib_seaborn_15\dataset_16_pandas\bollywood.csv",index_col="movie").squeeze()

movie
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# series method 

# head and tail

movie.head()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
# Name: lead, dtype: object

# %%
movie.head(4)
# Out:
# movie
# Uri: The Surgical Strike                Vicky Kaushal
# Battalion 609                             Vicky Ahuja
# The Accidental Prime Minister (film)      Anupam Kher
# Why Cheat India                         Emraan Hashmi
# Name: lead, dtype: object

# %%
movie.tail()
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
movie.tail(2)
# Out:
# movie
# Company (film)            Ajay Devgn
# Awara Paagal Deewana    Akshay Kumar
# Name: lead, dtype: object

# %%
# sample 
movie.sample()
# Out:
# movie
# Paltan (film)    Jackie Shroff
# Name: lead, dtype: object

# %%
movie.sample(3) # randomly selects 3 rows
# Out:
# movie
# Girlfriend (2004 film)      Isha Koppikar
# Dhoom 3                        Aamir Khan
# Dunno Y... Na Jaane Kyon      Zeenat Aman
# Name: lead, dtype: object

# %%
# value counts

movie.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values

#finding kohli highest and lowest runs

# temporary changes 

kohli.sort_values(ascending=False).head(1).values[0]
# Out:
# 113

# %%
# for permanent changes 

#    kohli.sort_values(ascending=False,inplace=True)

# %%
# sort_index

# temporay changes 
movie.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
# for permanent changes 

# movie.sort_index(inplace=True)

# %%
# series maths methods

# count

kohli.count()
# Out:
# 215

# %%
# sum
kohli.sum()
# Out:
# 6634

# %%
# prod
kohli.prod()
# Out:
# 0

# %%
# mean ,median ,var,std

print(kohli.mean())
print(kohli.var())
print(kohli.std())
print(kohli.median())
print(kohli.mode())
# Out:
# 30.855813953488372
# 688.0024777222344
# 26.22980132830278
# 24.0
# 0    0
# Name: runs, dtype: int64

# %%
# min/max

kohli.min()
# Out:
# 0

# %%
kohli.max()
# Out:
# 113

# %%
# describe

kohli.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
# series indexing


# positive 
noodle=pd.Series(["wai wai","Rumpum","Preeti"])
noodle[1]
# Out:
# 'Rumpum'

# %%
# noodle[-1]
# In pandas Series, indexing is label-based, not purely positional.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 noodle[-1]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# ...

# %%
# slicing

kohli[1:5]
# Out:
# match_no
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
kohli[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# fancy indexing

kohli[[1,2,3,4,]]
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# Name: runs, dtype: int64

# %%
# fancy indexing
# indexing with label

movie['Uri: The Surgical Strike']
# Out:
# 'Vicky Kaushal'

# %%
# editing series 

# using indexing

fruits=pd.Series(["Apple","Mango","Banana","Orange"])
fruits[0]="Grapes"

fruits
# Out:
# 0    Grapes
# 1     Mango
# 2    Banana
# 3    Orange
# dtype: object

# %%
#   slicing
fruits[0:3]="safal","manish","sanjay"
fruits
# Out:
# 0     safal
# 1    manish
# 2    sanjay
# 3    Orange
# dtype: object

# %%
#fancy indexing

# loc → label-based indexing  its like bus number ab1 ab2
# iloc → position-based indexing its like 1st seat     , 2nd seat 



fruits.iloc[[1,2]]=["Ashish","Basnet"]
fruits
# Out:
# 0     safal
# 1    Ashish
# 2    Basnet
# 3    Orange
# dtype: object

# %%
# series with python functionalities 


# len/type/sorted/min/max/dir
print(len(fruits))

print(type(fruits))

print(sorted(fruits))

print(max(fruits))

print(min(fruits))

print(dir(fruits))
# Out:
# 4
# <class 'pandas.core.series.Series'>
# ['Ashish', 'Basnet', 'Orange', 'safal']
# safal
# Ashish
# ...

# %%
# type conversion

list(fruits)
# Out:
# ['safal', 'Ashish', 'Basnet', 'Orange']

# %%
dict(fruits)
# Out:
# {0: 'safal', 1: 'Ashish', 2: 'Basnet', 3: 'Orange'}

# %%
# membership operator
# search on index

"Lagaan" in movie
# Out:
# False

# %%
"sultan" not in movie
# Out:
# True

# %%
movie
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
"Evening Shadows" in movie
# Out:
# True

# %%
# search on values

"Ajay Devgn" in movie.values
# Out:
# True

# %%
# looping

# search on values 

# for i in movie:
 #   print(i)

# %%
# search in index
# for i in  movie.index:
  #  print(i)

# %%
# arithmetic operators( broadcasting concept)
score=pd.Series([100,34,56,78,90])
score-10
# Out:
# 0    90
# 1    24
# 2    46
# 3    68
# 4    80
# dtype: int64

# %%
score * 0
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
# relational operator 

kohli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
kohli>30
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
# boolean indexing in series 

# find no of 50 s and 100 scoreb by kohli

kohli>=50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
kohli[kohli>=50].size
# Out:
# 50

# %%
# no of ducks

kohli[kohli==0].size
# Out:
# 9

# %%
# find the actors who have done more than 20 movies
no=movie.value_counts()
no
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
no[no>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
# plotting graphs in pandas


kohli.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
movie.value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: xlabel='lead'>

# %%
movie.value_counts().head(20).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
# some important series method 


# astype
import sys
sys.getsizeof(kohli)
# Out:
# 3472

# %%
kohli.astype('int')
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int16

# %% [raw]
# sys.getsizeof(kohli.astype('int16'))

# %%
# betweeen
kohli.between(50,70)
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213    False
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
kohli[kohli.between(50,70)] # both are inclusive
# Out:
# match_no
# 15     50
# 34     58
# 44     56
# 45     67
# 52     70
# 57     57
# 71     51
# 73     58
# 74     65
# 80     57
# 85     56
# 97     67
# 103    51
# 104    62
# 122    52
# 129    54
# 131    54
# 132    62
# 134    64
# 137    55
# 141    58
# 144    57
# 148    68
# 152    70
# 162    67
# 182    50
# 197    51
# 198    53
# 209    58
# Name: runs, dtype: int64

# %%
# clip
kohli.clip(45,55)
# Out:
# match_no
# 1      45
# 2      45
# 3      45
# 4      45
# 5      45
#        ..
# 211    45
# 212    45
# 213    55
# 214    45
# 215    45
# Name: runs, Length: 215, dtype: int64

# %%
# drop-_duplicates()

dupli=pd.Series([1,1,2,3,4,4,5,6,7,7])
dupli
# Out:
# 0    1
# 1    1
# 2    2
# 3    3
# 4    4
# 5    4
# 6    5
# 7    6
# 8    7
# 9    7
# dtype: int64

# %%
dupli.drop_duplicates()
# Out:
# 0    1
# 2    2
# 3    3
# 4    4
# 6    5
# 7    6
# 8    7
# dtype: int64

# %%
dupli.drop_duplicates(keep="last")
# Out:
# 1    1
# 2    2
# 3    3
# 5    4
# 6    5
# 7    6
# 9    7
# dtype: int64

# %%
# drop duplicated 

dupli.duplicated().sum()
# Out:
# 3

# %%
# handling missing value


dupli=pd.Series([1,1,2,np.nan,3,4,4,np.nan,5,6,7,7])
dupli
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     NaN
# 4     3.0
# 5     4.0
# 6     4.0
# 7     NaN
# 8     5.0
# 9     6.0
# 10    7.0
# 11    7.0
# dtype: float64

# %%
dupli.size
# Out:
# 12

# %%
dupli.count()
# Out:
# 10

# %%
dupli.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
dupli.isnull().sum()
# Out:
# 2

# %%
# dropna

dupli.dropna()
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 4     3.0
# 5     4.0
# 6     4.0
# 8     5.0
# 9     6.0
# 10    7.0
# 11    7.0
# dtype: float64

# %%
# fillna

dupli.fillna(dupli.mean())
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     4.0
# 4     3.0
# 5     4.0
# 6     4.0
# 7     4.0
# 8     5.0
# 9     6.0
# 10    7.0
# 11    7.0
# dtype: float64

# %%
dupli.fillna(1.5)
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     1.5
# 4     3.0
# 5     4.0
# 6     4.0
# 7     1.5
# 8     5.0
# 9     6.0
# 10    7.0
# 11    7.0
# dtype: float64

# %%
# isin

kohli.isin([25,67,89])
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213    False
# 214     True
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
kohli[kohli.isin([25,67,89])]
# Out:
# match_no
# 45     67
# 79     25
# 97     67
# 162    67
# 168    25
# 193    25
# 196    25
# 214    25
# Name: runs, dtype: int64

# %%
#apply
kohli.apply(lambda x:"good inning" if x>kohli.mean() else "bad innings")
# Out:
# match_no
# 1      bad innings
# 2      bad innings
# 3      bad innings
# 4      bad innings
# 5      bad innings
#           ...
# 211    bad innings
# 212    bad innings
# 213    good inning
# 214    bad innings
# 215    bad innings
# Name: runs, Length: 215, dtype: object

# %%
movie.apply(lambda x:x.split())
# Out:
# movie
# Uri: The Surgical Strike                   [Vicky, Kaushal]
# Battalion 609                                [Vicky, Ahuja]
# The Accidental Prime Minister (film)         [Anupam, Kher]
# Why Cheat India                            [Emraan, Hashmi]
# Evening Shadows                         [Mona, Ambegaonkar]
#                                                ...
# Hum Tumhare Hain Sanam                   [Shah, Rukh, Khan]
# Aankhen (2002 film)                     [Amitabh, Bachchan]
# Saathiya (film)                             [Vivek, Oberoi]
# Company (film)                                [Ajay, Devgn]
# Awara Paagal Deewana                        [Akshay, Kumar]
# Name: lead, Length: 1500, dtype: object

# %%
movie.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
# copy 

# conceptual

new=kohli.head()
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1]=500
new
# Out:
# match_no
# 1    500
# 2     23
# 3     13
# 4     12
# 5      1
# 0    500
# Name: runs, dtype: int64

# %%
kohli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
