# %%
#
#try except 

with open(r"C:\Users\acer\Python-Sql-1\demo.txt",'r') as f:
    print(f.read())
# Out:
# Aaman

# %%
try:
    
    with open(r"C:\Users\acer\Python-Sql-1\demo1.txt",'r') as f:
        print(f.read())

except:
    print('file not found')
# Out:
# file not found
